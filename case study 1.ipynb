# %%
import pandas as pd
import numpy as np
oj = pd.read_csv('C:\\Users\\Administrator\\Desktop\\python\\assignment\\DataSets\\oj.csv')
# Out:
#    store      brand  week   logmove  feat  price     AGE60      EDUC   ETHNIC  \
# 0      2  tropicana    40  9.018695     0   3.87  0.232865  0.248935  0.11428
# 1      2  tropicana    46  8.723231     0   3.87  0.232865  0.248935  0.11428
# 2      2  tropicana    47  8.253228     0   3.87  0.232865  0.248935  0.11428
# 3      2  tropicana    48  8.987197     0   3.87  0.232865  0.248935  0.11428
# 4      2  tropicana    50  9.093357     0   3.87  0.232865  0.248935  0.11428
#
#       INCOME   HHLARGE   WORKWOM   HVAL150  SSTRDIST   SSTRVOL  CPDIST5  \
# 0  10.553205  0.103953  0.303585  0.463887  2.110122  1.142857  1.92728
# 1  10.553205  0.103953  0.303585  0.463887  2.110122  1.142857  1.92728
# 2  10.553205  0.103953  0.303585  0.463887  2.110122  1.142857  1.92728
# 3  10.553205  0.103953  0.303585  0.463887  2.110122  1.142857  1.92728
# 4  10.553205  0.103953  0.303585  0.463887  2.110122  1.142857  1.92728
#
#     CPWVOL5
# 0  0.376927
# 1  0.376927
# 2  0.376927
# 3  0.376927
# 4  0.376927

# %%
#1.	Find the dimensions of the oj data set
np.shape(oj)
# Out:
# (28947, 17)

# %%
#2.	Find the structure of the data set
oj.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28947 entries, 0 to 28946
# Data columns (total 17 columns):
# store       28947 non-null int64
# brand       28947 non-null object
# week        28947 non-null int64
# logmove     28947 non-null float64
# feat        28947 non-null int64
# price       28947 non-null float64
# AGE60       28947 non-null float64
# EDUC        28947 non-null float64
# ETHNIC      28947 non-null float64
# INCOME      28947 non-null float64
# HHLARGE     28947 non-null float64
# WORKWOM     28947 non-null float64
# HVAL150     28947 non-null float64
# SSTRDIST    28947 non-null float64
# SSTRVOL     28947 non-null float64
# CPDIST5     28947 non-null float64
# CPWVOL5     28947 non-null float64
# dtypes: float64(13), int64(3), object(1)
# memory usage: 3.8+ MB

# %%
#3.	Find out the column names in the data set
oj.columns
# Out:
# Index([u'store', u'brand', u'week', u'logmove', u'feat', u'price', u'AGE60',
#        u'EDUC', u'ETHNIC', u'INCOME', u'HHLARGE', u'WORKWOM', u'HVAL150',
#        u'SSTRDIST', u'SSTRVOL', u'CPDIST5', u'CPWVOL5'],
#       dtype='object')

# %%
#4.	Describe the data set
oj.describe()
# Out:
#               store          week       logmove          feat         price  \
# count  28947.000000  28947.000000  28947.000000  28947.000000  28947.000000
# mean      80.883511    100.459944      9.167864      0.237261      2.282488
# std       35.576511     34.692314      1.019378      0.425411      0.648001
# min        2.000000     40.000000      4.158883      0.000000      0.520000
# 25%       53.000000     70.000000      8.489616      0.000000      1.790000
# 50%       86.000000    101.000000      9.034080      0.000000      2.170000
# 75%      111.000000    130.000000      9.764685      0.000000      2.730000
# max      137.000000    160.000000     13.482016      1.000000      3.870000
#
#               AGE60          EDUC        ETHNIC        INCOME       HHLARGE  \
# count  28947.000000  28947.000000  28947.000000  28947.000000  28947.000000
# mean       0.173130      0.225220      0.155557     10.616735      0.115602
# std        0.061872      0.109945      0.187581      0.282314      0.030168
# min        0.058054      0.049550      0.024247      9.867083      0.013506
# 25%        0.122100      0.145985      0.041910     10.456079      0.097938
# 50%        0.170655      0.229390      0.074656     10.635326      0.111221
# 75%        0.213949      0.284395      0.187761     10.796960      0.135168
# max        0.307398      0.528362      0.995691     11.236197      0.216354
#
#             WORKWOM       HVAL150      SSTRDIST       SSTRVOL       CPDIST5  \
# count  28947.000000  28947.000000  28947.000000  28947.000000  28947.000000
# mean       0.359178      0.343766      5.097274      1.207317      2.120359
# std        0.052673      0.239028      3.472386      0.526528      0.729828
# min        0.244463      0.002509      0.132097      0.400000      0.772530
# 25%        0.312636      0.123486      2.767046      0.727273      1.626192
# 50%        0.355635      0.346154      4.650687      1.115385      1.963412
# 75%        0.402313      0.528313      6.650602      1.538462      2.533672
# max        0.472308      0.916699     17.855951      2.571429      4.107902
#
#             CPWVOL5
# count  28947.000000
# mean       0.438914
# std        0.219248
# min        0.094562
# 25%        0.271673
# 50%        0.383227
# 75%        0.560240
# max        1.143367

# %%
#1.	Fetch the first row 3rd column from the data set
oj.iloc[0,3]
# Out:
# 9.018695487999999

# %%
#2.	Fetch the first, second and Third columns of the oj data frame
fithree = oj.iloc[:,:3]
fithree.head()
# Out:
#    store      brand  week
# 0      2  tropicana    40
# 1      2  tropicana    46
# 2      2  tropicana    47
# 3      2  tropicana    48
# 4      2  tropicana    50

# %%
#3.	Fetch the first, second, eighth and the 456th rows of the 1st, third and the sixth columns of the data frame
oj.iloc[[0,1,7,455],[0,2,5]]
# Out:
#      store  week  price
# 0        2    40   3.87
# 1        2    46   3.87
# 7        2    53   3.29
# 455      5    51   2.99

# %%
#4.	Fetch the top 5 rows of the brand column\
oj.iloc[:5,:]
# Out:
#    store      brand  week   logmove  feat  price     AGE60      EDUC   ETHNIC  \
# 0      2  tropicana    40  9.018695     0   3.87  0.232865  0.248935  0.11428
# 1      2  tropicana    46  8.723231     0   3.87  0.232865  0.248935  0.11428
# 2      2  tropicana    47  8.253228     0   3.87  0.232865  0.248935  0.11428
# 3      2  tropicana    48  8.987197     0   3.87  0.232865  0.248935  0.11428
# 4      2  tropicana    50  9.093357     0   3.87  0.232865  0.248935  0.11428
#
#       INCOME   HHLARGE   WORKWOM   HVAL150  SSTRDIST   SSTRVOL  CPDIST5  \
# 0  10.553205  0.103953  0.303585  0.463887  2.110122  1.142857  1.92728
# 1  10.553205  0.103953  0.303585  0.463887  2.110122  1.142857  1.92728
# 2  10.553205  0.103953  0.303585  0.463887  2.110122  1.142857  1.92728
# 3  10.553205  0.103953  0.303585  0.463887  2.110122  1.142857  1.92728
# 4  10.553205  0.103953  0.303585  0.463887  2.110122  1.142857  1.92728
#
#     CPWVOL5
# 0  0.376927
# 1  0.376927
# 2  0.376927
# 3  0.376927
# 4  0.376927

# %%
#5.	Fetch top 5 rows of the brand, week and feat details
oj.loc[:5,['brand','week','feat']]
# Out:
#        brand  week  feat
# 0  tropicana    40     0
# 1  tropicana    46     0
# 2  tropicana    47     0
# 3  tropicana    48     0
# 4  tropicana    50     0
# 5  tropicana    51     0

# %%
#6.	Fetch the details of all distinct stores
oj.store.unique()
# Out:
# array([  2,   5,   8,   9,  12,  14,  18,  21,  28,  32,  33,  40,  44,
#         45,  47,  48,  49,  50,  51,  52,  53,  54,  56,  59,  62,  64,
#         67,  68,  70,  71,  72,  73,  74,  75,  76,  77,  78,  80,  81,
#         83,  84,  86,  88,  89,  90,  91,  92,  93,  94,  95,  97,  98,
#        100, 101, 102, 103, 104, 105, 106, 107, 109, 110, 111, 112, 113,
#        114, 115, 116, 117, 118, 119, 121, 122, 123, 124, 126, 128, 129,
#        130, 131, 132, 134, 137], dtype=int64)

# %%
#7.	Fetch all the observations for Tropicana brand
tro=oj[oj.brand=='tropicana']
tro.head()
# Out:
#    store      brand  week   logmove  feat  price     AGE60      EDUC   ETHNIC  \
# 0      2  tropicana    40  9.018695     0   3.87  0.232865  0.248935  0.11428
# 1      2  tropicana    46  8.723231     0   3.87  0.232865  0.248935  0.11428
# 2      2  tropicana    47  8.253228     0   3.87  0.232865  0.248935  0.11428
# 3      2  tropicana    48  8.987197     0   3.87  0.232865  0.248935  0.11428
# 4      2  tropicana    50  9.093357     0   3.87  0.232865  0.248935  0.11428
#
#       INCOME   HHLARGE   WORKWOM   HVAL150  SSTRDIST   SSTRVOL  CPDIST5  \
# 0  10.553205  0.103953  0.303585  0.463887  2.110122  1.142857  1.92728
# 1  10.553205  0.103953  0.303585  0.463887  2.110122  1.142857  1.92728
# 2  10.553205  0.103953  0.303585  0.463887  2.110122  1.142857  1.92728
# 3  10.553205  0.103953  0.303585  0.463887  2.110122  1.142857  1.92728
# 4  10.553205  0.103953  0.303585  0.463887  2.110122  1.142857  1.92728
#
#     CPWVOL5   LogInc
# 0  0.376927  2.35643
# 1  0.376927  2.35643
# 2  0.376927  2.35643
# 3  0.376927  2.35643
# 4  0.376927  2.35643

# %%
#8.	Fetch all the observations for Tropicana brand using query function
trop=oj.query("brand=='tropicana'")
trop.head()
# Out:
#    store      brand  week   logmove  feat  price     AGE60      EDUC   ETHNIC  \
# 0      2  tropicana    40  9.018695     0   3.87  0.232865  0.248935  0.11428
# 1      2  tropicana    46  8.723231     0   3.87  0.232865  0.248935  0.11428
# 2      2  tropicana    47  8.253228     0   3.87  0.232865  0.248935  0.11428
# 3      2  tropicana    48  8.987197     0   3.87  0.232865  0.248935  0.11428
# 4      2  tropicana    50  9.093357     0   3.87  0.232865  0.248935  0.11428
#
#       INCOME   HHLARGE   WORKWOM   HVAL150  SSTRDIST   SSTRVOL  CPDIST5  \
# 0  10.553205  0.103953  0.303585  0.463887  2.110122  1.142857  1.92728
# 1  10.553205  0.103953  0.303585  0.463887  2.110122  1.142857  1.92728
# 2  10.553205  0.103953  0.303585  0.463887  2.110122  1.142857  1.92728
# 3  10.553205  0.103953  0.303585  0.463887  2.110122  1.142857  1.92728
# 4  10.553205  0.103953  0.303585  0.463887  2.110122  1.142857  1.92728
#
#     CPWVOL5
# 0  0.376927
# 1  0.376927
# 2  0.376927
# 3  0.376927
# 4  0.376927

# %%
#9.	Fetch bottom 5 observations for those who have bought Tropicana or dominics
tod=oj[(oj.brand=='tropicana') | (oj.brand=='dominics')]
tod.tail()
# Out:
#        store      brand  week    logmove  feat  price     AGE60      EDUC  \
# 28746    137  tropicana   156  11.313498     1   2.49  0.209602  0.528362
# 28747    137  tropicana   157  10.628133     0   2.66  0.209602  0.528362
# 28748    137  tropicana   158   9.936535     0   3.11  0.209602  0.528362
# 28749    137  tropicana   159  10.855917     1   2.79  0.209602  0.528362
# 28750    137  tropicana   160  10.236525     0   2.88  0.209602  0.528362
#
#         ETHNIC    INCOME   HHLARGE   WORKWOM   HVAL150  SSTRDIST   SSTRVOL  \
# 28746  0.11325  10.96649  0.092996  0.330293  0.860739  6.026484  0.705882
# 28747  0.11325  10.96649  0.092996  0.330293  0.860739  6.026484  0.705882
# 28748  0.11325  10.96649  0.092996  0.330293  0.860739  6.026484  0.705882
# 28749  0.11325  10.96649  0.092996  0.330293  0.860739  6.026484  0.705882
# 28750  0.11325  10.96649  0.092996  0.330293  0.860739  6.026484  0.705882
#
#        CPDIST5   CPWVOL5
# 28746  0.77253  0.333761
# 28747  0.77253  0.333761
# 28748  0.77253  0.333761
# 28749  0.77253  0.333761
# 28750  0.77253  0.333761

# %%
#10.	Fetch the income, brand, price observations with Tropicana brand without feature advertisement
x=oj.loc[(oj.brand=='tropicana') & (oj.feat==0),['INCOME','brand','price']]
x.head()
# Out:
#       INCOME      brand  price
# 0  10.553205  tropicana   3.87
# 1  10.553205  tropicana   3.87
# 2  10.553205  tropicana   3.87
# 3  10.553205  tropicana   3.87
# 4  10.553205  tropicana   3.87

# %%
#11.	Add a new column in the dataset: logInc which is the logarithm of the income
oj['LogInc']=np.log(oj.INCOME)
oj.head()
#LogInc=np.log(oj.INCOME)
#oj['LogInc']=LogInc
#oj.head()
# Out:
#    store      brand  week   logmove  feat  price     AGE60      EDUC   ETHNIC  \
# 0      2  tropicana    40  9.018695     0   3.87  0.232865  0.248935  0.11428
# 1      2  tropicana    46  8.723231     0   3.87  0.232865  0.248935  0.11428
# 2      2  tropicana    47  8.253228     0   3.87  0.232865  0.248935  0.11428
# 3      2  tropicana    48  8.987197     0   3.87  0.232865  0.248935  0.11428
# 4      2  tropicana    50  9.093357     0   3.87  0.232865  0.248935  0.11428
#
#       INCOME   HHLARGE   WORKWOM   HVAL150  SSTRDIST   SSTRVOL  CPDIST5  \
# 0  10.553205  0.103953  0.303585  0.463887  2.110122  1.142857  1.92728
# 1  10.553205  0.103953  0.303585  0.463887  2.110122  1.142857  1.92728
# 2  10.553205  0.103953  0.303585  0.463887  2.110122  1.142857  1.92728
# 3  10.553205  0.103953  0.303585  0.463887  2.110122  1.142857  1.92728
# 4  10.553205  0.103953  0.303585  0.463887  2.110122  1.142857  1.92728
#
#     CPWVOL5   LogInc
# 0  0.376927  2.35643
# 1  0.376927  2.35643
# 2  0.376927  2.35643
# 3  0.376927  2.35643
# 4  0.376927  2.35643

# %%
#12	Sort the Data in the increasing order of the week
oj.sort_values('week').head()
# Out:
#        store        brand  week   logmove  feat  price     AGE60      EDUC  \
# 0          2    tropicana    40  9.018695     0   3.87  0.232865  0.248935
# 8141      59  minute.maid    40  7.655391     0   2.62  0.110819  0.233036
# 8025      59    tropicana    40  8.489616     0   3.19  0.110819  0.233036
# 26035    124  minute.maid    40  8.269757     0   3.17  0.119626  0.261876
# 7907      56    dominicks    40  8.565602     1   1.59  0.192889  0.237551
#
#          ETHNIC     INCOME   HHLARGE   WORKWOM   HVAL150  SSTRDIST   SSTRVOL  \
# 0      0.114280  10.553205  0.103953  0.303585  0.463887  2.110122  1.142857
# 8141   0.024247  10.715040  0.140676  0.390696  0.292652  0.217275  1.000000
# 8025   0.024247  10.715040  0.140676  0.390696  0.292652  0.217275  1.000000
# 26035  0.572356  10.258957  0.124950  0.348519  0.416316  6.328747  0.727273
# 7907   0.041356  10.831825  0.105928  0.362168  0.578125  4.865721  0.533333
#
#         CPDIST5   CPWVOL5    LogInc
# 0      1.927280  0.376927  2.356430
# 8141   3.331154  0.395539  2.371648
# 8025   3.331154  0.395539  2.371648
# 26035  1.793796  0.202169  2.328151
# 7907   2.998578  0.496127  2.382489

# %%
#13.	Sort the data in the decreasing order of Income
oj.sort_values('INCOME',ascending=0).head()
# Out:
#       store        brand  week    logmove  feat  price     AGE60     EDUC  \
# 8379     62    tropicana    46   9.264829     0   3.87  0.222534  0.51776
# 8508     62  minute.maid    59   8.540910     0   3.17  0.222534  0.51776
# 8488     62    tropicana   159  10.263676     1   2.79  0.222534  0.51776
# 8489     62    tropicana   160   9.609922     0   2.97  0.222534  0.51776
# 8490     62  minute.maid    40   8.449343     0   3.17  0.222534  0.51776
#
#         ETHNIC     INCOME   HHLARGE   WORKWOM   HVAL150  SSTRDIST   SSTRVOL  \
# 8379  0.026511  11.236197  0.103979  0.322765  0.916699  5.452685  0.705882
# 8508  0.026511  11.236197  0.103979  0.322765  0.916699  5.452685  0.705882
# 8488  0.026511  11.236197  0.103979  0.322765  0.916699  5.452685  0.705882
# 8489  0.026511  11.236197  0.103979  0.322765  0.916699  5.452685  0.705882
# 8490  0.026511  11.236197  0.103979  0.322765  0.916699  5.452685  0.705882
#
#       CPDIST5   CPWVOL5   LogInc
# 8379  2.18405  0.201722  2.41914
# 8508  2.18405  0.201722  2.41914
# 8488  2.18405  0.201722  2.41914
# 8489  2.18405  0.201722  2.41914
# 8490  2.18405  0.201722  2.41914

# %%
#14.	Find the mean of the juice price for each brand
oj.groupby('brand')['price'].mean()
# Out:
# brand
# dominicks      1.735809
# minute.maid    2.241162
# tropicana      2.870493
# Name: price, dtype: float64

# %%
#15.	Find the average income for each brand and at each store
oj.groupby(['brand','store'])['price'].mean()
# Out:
# brand      store
# dominicks  2        1.791273
#            5        1.733707
#            8        1.664322
#            9        1.702308
#            12       1.841826
#            14       1.825897
#            18       1.653750
#            21       1.610917
#            28       1.755043
#            32       1.831667
#            33       1.842222
#            40       1.576460
#            44       1.713879
#            45       1.705966
#            47       1.752982
#            48       1.757119
#            49       1.726903
#            50       1.705763
#            51       1.746786
#            52       1.841043
#            53       1.829496
#            54       1.745702
#            56       1.730254
#            59       1.588448
#            62       1.833675
#            64       1.728505
#            67       1.666379
#            68       1.842435
#            70       1.604167
#            71       1.831913
#                       ...
# tropicana  101      2.897355
#            102      2.728696
#            103      2.733826
#            104      2.891130
#            105      2.760252
#            106      2.895966
#            107      2.924917
#            109      3.036555
#            110      2.920855
#            111      3.011250
#            112      2.735254
#            113      2.916975
#            114      2.772821
#            115      2.841802
#            116      2.901197
#            117      2.941356
#            118      2.979748
#            119      2.812101
#            121      2.763051
#            122      2.614050
#            123      3.009250
#            124      3.035372
#            126      2.890672
#            128      2.998151
#            129      2.809138
#            130      2.973158
#            131      2.893534
#            132      2.740000
#            134      2.665057
#            137      2.883980
# Name: price, Length: 249, dtype: float64

# %%
#a.	Mean and std deviation of the income
x=oj.INCOME.mean()
y=oj.INCOME.std()
print('mean='+str(x)+',standard dev='+str(y))
# Out:
# mean=10.616734638,standard dev=0.282313621503

# %%
#b.	For income greater than or equal to 10.5, find the mean income
x=oj[oj.INCOME>=10.5]
x.INCOME.mean()
# Out:
# 10.759452382031103

# %%
#c.	For each brand having price >=2.5 find the mean, median, sd of the log of income
x=oj[oj.price>=2.5]
me=x.groupby('brand').mean()
std=x.groupby('brand').std()
med=x.groupby('brand').median()
print(' \n  mean= \n '+str(me.INCOME))
print(' \n  median=\n  '+str(med.INCOME))
print(' \n standard dev=\n  '+str(std.INCOME))
# Out:
#
#   mean=
#  brand
# dominicks      10.473626
# minute.maid    10.601137
# tropicana      10.615601
# Name: INCOME, dtype: float64
#
#   median=
#   brand
# dominicks      10.367190
# minute.maid    10.632364
# tropicana      10.635326
# Name: INCOME, dtype: float64
#
#  standard dev=
#   brand
# dominicks      0.410146
# minute.maid    0.300719
# tropicana      0.282522
# Name: INCOME, dtype: float64

# %%
#17.	Find the Cross tabulation of brands and feature advertisement
pd.crosstab(oj.brand,oj.feat)
# Out:
# feat            0     1
# brand
# dominicks    7169  2480
# minute.maid  6865  2784
# tropicana    8045  1604
